# %%
# Import the libraries

import numpy as np
import pandas as pd

# %%
# Loading the dataframes

match = pd.read_csv('ipl_match_data_2008_2023.csv')
delivery = pd.read_csv('ipl_ball_by_ball_data_2008_2023.csv', low_memory=False)

# %%
# Viewing the match Dataset

match.head()
# Out:
#        id        date   season             event_name match_type match_number  \
# 0  335982  18-04-2008  2007/08  Indian Premier League        T20            1
# 1  335983  19-04-2008  2007/08  Indian Premier League        T20            2
# 2  335984  19-04-2008  2007/08  Indian Premier League        T20            3
# 3  335986  20-04-2008  2007/08  Indian Premier League        T20            4
# 4  335985  20-04-2008  2007/08  Indian Premier League        T20            5
#
#          city                                       venue  \
# 0   Bangalore                       M Chinnaswamy Stadium
# 1  Chandigarh  Punjab Cricket Association Stadium, Mohali
# 2       Delhi                            Feroz Shah Kotla
# 3     Kolkata                                Eden Gardens
# 4      Mumbai                            Wankhede Stadium
#
#                          team1                        team2  ...  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders  ...
# ...

# %%
# There were total 1024 IPL Matches played till the season of 2023

match.shape
# Out:
# (1024, 26)

# %%
# Datatype of each column in the 'match' Dataset

match.dtypes
# Out:
# id                   int64
# date                object
# season              object
# event_name          object
# match_type          object
# match_number        object
# city                object
# venue               object
# team1               object
# team2               object
# referee             object
# reserve_umpire      object
# tv_umpire           object
# umpire1             object
# umpire2             object
# team1players        object
# team2players        object
# toss_winner         object
# toss_decision       object
# winner              object
# result              object
# eliminator          object
# wonBy               object
# margin             float64
# method              object
# player_of_match     object
# dtype: object

# %%
match['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Kolkata Knight Riders', 'Mumbai Indians',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans'], dtype=object)

# %%
# Changing names of teams in match dataset

match['team1'].replace('Royal Challengers Bangalore', 'Royal Challengers Bengaluru', inplace=True)
match['team2'].replace('Royal Challengers Bangalore', 'Royal Challengers Bengaluru', inplace=True)
match['winner'].replace('Royal Challengers Bangalore', 'Royal Challengers Bengaluru', inplace=True)
match['toss_winner'].replace('Royal Challengers Bangalore', 'Royal Challengers Bengaluru', inplace=True)

match['team1'].replace('Deccan Chargers', 'Sunrisers Hyderabad', inplace=True)
match['team2'].replace('Deccan Chargers', 'Sunrisers Hyderabad', inplace=True)
match['winner'].replace('Deccan Chargers', 'Sunrisers Hyderabad', inplace=True)
match['toss_winner'].replace('Deccan Chargers', 'Sunrisers Hyderabad', inplace=True)

match['team1'].replace('Kings XI Punjab', 'Punjab Kings', inplace=True)
match['team2'].replace('Kings XI Punjab', 'Punjab Kings', inplace=True)
match['winner'].replace('Kings XI Punjab', 'Punjab Kings', inplace=True)
match['toss_winner'].replace('Kings XI Punjab', 'Punjab Kings', inplace=True)

match['team1'].replace('Delhi Daredevils', 'Delhi Capitals', inplace=True)
match['team2'].replace('Delhi Daredevils', 'Delhi Capitals', inplace=True)
match['winner'].replace('Delhi Daredevils', 'Delhi Capitals', inplace=True)
match['toss_winner'].replace('Delhi Daredevils', 'Delhi Capitals', inplace=True)

# %%
# Loading the 'delivery' dataset

delivery.head()
# Out:
#        id   season                  venue           batting_team  \
# 0  335982  2007/08  M Chinnaswamy Stadium  Kolkata Knight Riders
# 1  335982  2007/08  M Chinnaswamy Stadium  Kolkata Knight Riders
# 2  335982  2007/08  M Chinnaswamy Stadium  Kolkata Knight Riders
# 3  335982  2007/08  M Chinnaswamy Stadium  Kolkata Knight Riders
# 4  335982  2007/08  M Chinnaswamy Stadium  Kolkata Knight Riders
#
#                   bowling_team  innings  over  ball  is_super_over  \
# 0  Royal Challengers Bangalore        1     0     1              0
# 1  Royal Challengers Bangalore        1     0     2              0
# 2  Royal Challengers Bangalore        1     0     3              0
# 3  Royal Challengers Bangalore        1     0     4              0
# 4  Royal Challengers Bangalore        1     0     5              0
#
#         batter  ... total_runs is_wkt_delivery  player_out  wkt_type  \
# 0   SC Ganguly  ...          1               0         NaN       NaN
# ...

# %%
# Some of the teams have changed their names, therefore their names must also be changed in this delivery dataset.

delivery['batting_team'].replace('Royal Challengers Bangalore', 'Royal Challengers Bengaluru', inplace=True)
delivery['bowling_team'].replace('Royal Challengers Bangalore', 'Royal Challengers Bengaluru', inplace=True)

delivery['batting_team'].replace('Deccan Chargers', 'Sunrisers Hyderabad', inplace=True)
delivery['bowling_team'].replace('Delhi Capitals', 'Sunrisers Hyderabad', inplace=True)

delivery['batting_team'].replace('Kings XI Punjab', 'Punjab Kings', inplace=True)
delivery['bowling_team'].replace('Kings XI Punjab', 'Punjab Kings', inplace=True)

delivery['batting_team'].replace('Delhi Daredevils', 'Delhi Capitals', inplace=True)
delivery['bowling_team'].replace('Delhi Daredevils', 'Delhi Capitals', inplace=True)
# delivery['over'] += 1
# delivery['over'] = delivery['over']

# %%
# Name is changed in the 'match' dataset

match.head()
# Out:
#        id        date   season             event_name match_type match_number  \
# 0  335982  18-04-2008  2007/08  Indian Premier League        T20            1
# 1  335983  19-04-2008  2007/08  Indian Premier League        T20            2
# 2  335984  19-04-2008  2007/08  Indian Premier League        T20            3
# 3  335986  20-04-2008  2007/08  Indian Premier League        T20            4
# 4  335985  20-04-2008  2007/08  Indian Premier League        T20            5
#
#          city                                       venue  \
# 0   Bangalore                       M Chinnaswamy Stadium
# 1  Chandigarh  Punjab Cricket Association Stadium, Mohali
# 2       Delhi                            Feroz Shah Kotla
# 3     Kolkata                                Eden Gardens
# 4      Mumbai                            Wankhede Stadium
#
#                          team1                        team2  ...  \
# 0  Royal Challengers Bengaluru        Kolkata Knight Riders  ...
# ...

# %%
# Name is changed in 'delivery' dataset

delivery.head()
# Out:
#        id   season                  venue           batting_team  \
# 0  335982  2007/08  M Chinnaswamy Stadium  Kolkata Knight Riders
# 1  335982  2007/08  M Chinnaswamy Stadium  Kolkata Knight Riders
# 2  335982  2007/08  M Chinnaswamy Stadium  Kolkata Knight Riders
# 3  335982  2007/08  M Chinnaswamy Stadium  Kolkata Knight Riders
# 4  335982  2007/08  M Chinnaswamy Stadium  Kolkata Knight Riders
#
#                   bowling_team  innings  over  ball  is_super_over  \
# 0  Royal Challengers Bengaluru        1     0     1              0
# 1  Royal Challengers Bengaluru        1     0     2              0
# 2  Royal Challengers Bengaluru        1     0     3              0
# 3  Royal Challengers Bengaluru        1     0     4              0
# 4  Royal Challengers Bengaluru        1     0     5              0
#
#         batter  ... total_runs is_wkt_delivery  player_out  wkt_type  \
# 0   SC Ganguly  ...          1               0         NaN       NaN
# ...

# %%
# 'id' column name of delivery dataset is changed to 'match_id' for easy understanding

delivery.rename(columns = {'id' : 'match_id'}, inplace = True)

# %%
# Datatypes of 'delivery' dataset

delivery.dtypes
# Out:
# match_id              int64
# season               object
# venue                object
# batting_team         object
# bowling_team         object
# innings               int64
# over                  int64
# ball                  int64
# is_super_over         int64
# batter               object
# non_striker          object
# bowler               object
# runs_off_bat          int64
# runs_from_extras      int64
# total_runs            int64
# is_wkt_delivery       int64
# player_out           object
# wkt_type             object
# fielders_involved    object
# byes                  int64
# legbyes               int64
# wides                 int64
# noballs               int64
# penalty               int64
# dtype: object

# %%
# Total runs of the first inning is calculated and 'reset_index()' is used to convert this data into dataframe

total_score_df = delivery.groupby(['match_id','innings']).sum()['total_runs'].reset_index()
total_score_df = total_score_df[total_score_df['innings'] == 1]
total_score_df
# Out:
#       match_id  innings  total_runs
# 0       335982        1         222
# 2       335983        1         240
# 4       335984        1         129
# 6       335985        1         165
# 8       335986        1         110
# ...        ...      ...         ...
# 2065   1359544        1         197
# 2067   1370350        1         172
# 2069   1370351        1         182
# 2071   1370352        1         233
# 2073   1370353        1         214
#
# [1024 rows x 3 columns]

# %%
# Merging the 'match_df' dataframe with the original 'match' dataset

match_df = match.merge(total_score_df[['match_id','total_runs']], left_on='id', right_on='match_id')
match_df
# Out:
#            id        date   season             event_name match_type  \
# 0      335982  18-04-2008  2007/08  Indian Premier League        T20
# 1      335983  19-04-2008  2007/08  Indian Premier League        T20
# 2      335984  19-04-2008  2007/08  Indian Premier League        T20
# 3      335986  20-04-2008  2007/08  Indian Premier League        T20
# 4      335985  20-04-2008  2007/08  Indian Premier League        T20
# ...       ...         ...      ...                    ...        ...
# 1019  1359544  21-05-2023     2023  Indian Premier League        T20
# 1020  1370350  23-05-2023     2023  Indian Premier League        T20
# 1021  1370351  24-05-2023     2023  Indian Premier League        T20
# 1022  1370352  26-05-2023     2023  Indian Premier League        T20
# 1023  1370353  29-05-2023     2023  Indian Premier League        T20
#
#      match_number        city                                       venue  \
# ...

# %%
match_df.dtypes
# Out:
# id                   int64
# date                object
# season              object
# event_name          object
# match_type          object
# match_number        object
# city                object
# venue               object
# team1               object
# team2               object
# referee             object
# reserve_umpire      object
# tv_umpire           object
# umpire1             object
# umpire2             object
# team1players        object
# team2players        object
# toss_winner         object
# toss_decision       object
# winner              object
# result              object
# eliminator          object
# wonBy               object
# margin             float64
# method              object
# player_of_match     object
# match_id             int64
# total_runs           int64
# dtype: object

# %%
# Various Teams have played in IPL so far.
# Therefore, some of the teams must be dropped which are not playing in the current season.

match_df['team1'].unique()
# Out:
# array(['Royal Challengers Bengaluru', 'Punjab Kings', 'Delhi Capitals',
#        'Kolkata Knight Riders', 'Mumbai Indians', 'Rajasthan Royals',
#        'Sunrisers Hyderabad', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Rising Pune Supergiant',
#        'Lucknow Super Giants', 'Gujarat Titans'], dtype=object)

# %%
# These are the teams which are currently playing in IPL.

teams = [
    'Sunrisers Hyderabad',
    'Mumbai Indians',
    'Royal Challengers Bengaluru',
    'Kolkata Knight Riders',
    'Punjab Kings',
    'Chennai Super Kings',
    'Rajasthan Royals',
    'Delhi Capitals',
    'Lucknow Super Giants',
    'Gujarat Titans'
]

# %%
# We need to keep the data of those teams only whose name is present in the current teams list.
# We have to discard the other teams' data which are not playing.

match_df = match_df[match_df['team1'].isin(teams)]
match_df = match_df[match_df['team2'].isin(teams)]

# %%
# As we can see here, there is the data left only for 909 matches. Earlier it were 1024.

match_df.shape
# Out:
# (909, 28)

# %%
# We will also remove the data of those matches which were affected due to rain.
# We will keep the data of those matches only where 'D/L' method wasn't used.

match_df = match_df[match_df['method'] != 'D/L']

# %%
# After removing the rain affected matches, we are left with only 892 Matches data.
# So far it has gone: 1024 -> 909 -> 892

match_df.shape
# Out:
# (892, 28)

# %%
# For the final dataset's POV, we need these four columns.

match_df = match_df[['match_id','city','winner','total_runs']]

# %%
# Now we are merging 'match_df' data with the 'delivery' dataset

delivery_df = match_df.merge(delivery,on='match_id')

# %%
# We are selecting here the 2nd innings data because our model will predict the probability for the 2nd innings


delivery_df = delivery_df[delivery_df['innings'] == 2]

# %%
delivery_df.shape
# Out:
# (103511, 27)

# %%
delivery_df.dtypes
# Out:
# match_id              int64
# city                 object
# winner               object
# total_runs_x          int64
# season               object
# venue                object
# batting_team         object
# bowling_team         object
# innings               int64
# over                  int64
# ball                  int64
# is_super_over         int64
# batter               object
# non_striker          object
# bowler               object
# runs_off_bat          int64
# runs_from_extras      int64
# total_runs_y          int64
# is_wkt_delivery       int64
# player_out           object
# wkt_type             object
# fielders_involved    object
# byes                  int64
# legbyes               int64
# wides                 int64
# noballs               int64
# penalty               int64
# dtype: object

# %%
# We have to create a new column 'current_score' for the 'delivery_df' dataset.
# This column will the tell the current score after every delivery in the match.

# delivery_df['current_score'] = delivery_df.groupby('match_id').cumsum()['total_runs_y']
# delivery_df['current_score'] = delivery_df.groupby(['total_runs_y', 'match_id'])['total_runs_y'].cumsum()
delivery_df['current_score'] = delivery_df.groupby('match_id')['total_runs_y'].transform(lambda x: x.cumsum())
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x   season  \
# 124       335982  Bangalore  Kolkata Knight Riders           222  2007/08
# 125       335982  Bangalore  Kolkata Knight Riders           222  2007/08
# 126       335982  Bangalore  Kolkata Knight Riders           222  2007/08
# 127       335982  Bangalore  Kolkata Knight Riders           222  2007/08
# 128       335982  Bangalore  Kolkata Knight Riders           222  2007/08
# ...          ...        ...                    ...           ...      ...
# 213874   1370352  Ahmedabad         Gujarat Titans           233     2023
# 213875   1370352  Ahmedabad         Gujarat Titans           233     2023
# 213876   1370352  Ahmedabad         Gujarat Titans           233     2023
# 213877   1370352  Ahmedabad         Gujarat Titans           233     2023
# 213878   1370352  Ahmedabad         Gujarat Titans           233     2023
#
#                                    venue                 batting_team  \
# ...

# %%
# We have to calculate the 'runs_left' during the chase now.
# Here '+1' is added as the target is always 1 run more than the 1st Innings score

delivery_df['runs_left'] = delivery_df['total_runs_x'] - delivery_df['current_score'] + 1

# %%
# Now we need to calculate the 'balls_left' in the chase.

delivery_df['balls_left'] = ((20 - (delivery_df['over']+1))*6 + (6 - delivery_df['ball']))
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x   season  \
# 124       335982  Bangalore  Kolkata Knight Riders           222  2007/08
# 125       335982  Bangalore  Kolkata Knight Riders           222  2007/08
# 126       335982  Bangalore  Kolkata Knight Riders           222  2007/08
# 127       335982  Bangalore  Kolkata Knight Riders           222  2007/08
# 128       335982  Bangalore  Kolkata Knight Riders           222  2007/08
# ...          ...        ...                    ...           ...      ...
# 213874   1370352  Ahmedabad         Gujarat Titans           233     2023
# 213875   1370352  Ahmedabad         Gujarat Titans           233     2023
# 213876   1370352  Ahmedabad         Gujarat Titans           233     2023
# 213877   1370352  Ahmedabad         Gujarat Titans           233     2023
# 213878   1370352  Ahmedabad         Gujarat Titans           233     2023
#
#                                    venue                 batting_team  \
# ...

# %%
delivery_df['player_out'] = delivery_df['player_out'].fillna("0")
delivery_df['player_out'] = delivery_df['player_out'].apply(lambda x:x if x == "0" else "1")
delivery_df['player_out'] = delivery_df['player_out'].astype('int')
# wickets = delivery_df.groupby('match_id').cumsum()['player_dismissed'].values
# wickets = delivery_df.groupby(['player_out', 'match_id'])['player_out'].cumsum().values
wickets = delivery_df.groupby('match_id')['player_out'].transform(lambda x: x.cumsum()).values
delivery_df['wickets'] = 10 - wickets
delivery_df.head()
# Out:
#      match_id       city                 winner  total_runs_x   season  \
# 124    335982  Bangalore  Kolkata Knight Riders           222  2007/08
# 125    335982  Bangalore  Kolkata Knight Riders           222  2007/08
# 126    335982  Bangalore  Kolkata Knight Riders           222  2007/08
# 127    335982  Bangalore  Kolkata Knight Riders           222  2007/08
# 128    335982  Bangalore  Kolkata Knight Riders           222  2007/08
#
#                      venue                 batting_team  \
# 124  M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 125  M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 126  M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 127  M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 128  M Chinnaswamy Stadium  Royal Challengers Bengaluru
#
#               bowling_team  innings  over  ...  fielders_involved  byes  \
# 124  Kolkata Knight Riders        2     0  ...                NaN     0
# ...

# %%
# Calculating the current run rate
# crr = runs/overs

delivery_df['crr'] = delivery_df['current_score'] / ( (delivery_df['over']) + (delivery_df['ball']/6) )
delivery_df['crr']
# Out:
# 124       6.000000
# 125       6.000000
# 126       4.000000
# 127       4.500000
# 128       4.800000
#             ...
# 213874    9.396226
# 213875    9.532710
# 213876    9.444444
# 213877    9.412844
# 213878    9.327273
# Name: crr, Length: 103511, dtype: float64

# %%
# Calculating the required run rate

delivery_df['rrr'] = (delivery_df['runs_left'] / delivery_df['balls_left']) * 6
delivery_df['rrr']
# Out:
# 124       11.193277
# 125       11.237288
# 126       11.333333
# 127       11.379310
# 128       11.426087
#             ...
# 213874    29.142857
# 213875    29.538462
# 213876    32.000000
# 213877    34.363636
# 213878    37.800000
# Name: rrr, Length: 103511, dtype: float64

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x   season  \
# 124       335982  Bangalore  Kolkata Knight Riders           222  2007/08
# 125       335982  Bangalore  Kolkata Knight Riders           222  2007/08
# 126       335982  Bangalore  Kolkata Knight Riders           222  2007/08
# 127       335982  Bangalore  Kolkata Knight Riders           222  2007/08
# 128       335982  Bangalore  Kolkata Knight Riders           222  2007/08
# ...          ...        ...                    ...           ...      ...
# 213874   1370352  Ahmedabad         Gujarat Titans           233     2023
# 213875   1370352  Ahmedabad         Gujarat Titans           233     2023
# 213876   1370352  Ahmedabad         Gujarat Titans           233     2023
# 213877   1370352  Ahmedabad         Gujarat Titans           233     2023
# 213878   1370352  Ahmedabad         Gujarat Titans           233     2023
#
#                                    venue                 batting_team  \
# ...

# %%
# Here, we are checking if the chasing team won or not.
# If chasing team won, result is 1, else it is 0.

def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

delivery_df['result'] = delivery_df.apply(result,axis=1)
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x   season  \
# 124       335982  Bangalore  Kolkata Knight Riders           222  2007/08
# 125       335982  Bangalore  Kolkata Knight Riders           222  2007/08
# 126       335982  Bangalore  Kolkata Knight Riders           222  2007/08
# 127       335982  Bangalore  Kolkata Knight Riders           222  2007/08
# 128       335982  Bangalore  Kolkata Knight Riders           222  2007/08
# ...          ...        ...                    ...           ...      ...
# 213874   1370352  Ahmedabad         Gujarat Titans           233     2023
# 213875   1370352  Ahmedabad         Gujarat Titans           233     2023
# 213876   1370352  Ahmedabad         Gujarat Titans           233     2023
# 213877   1370352  Ahmedabad         Gujarat Titans           233     2023
# 213878   1370352  Ahmedabad         Gujarat Titans           233     2023
#
#                                    venue                 batting_team  \
# ...

# %%
# Creating a final DataFrame with all the required columns.

final_df = delivery_df[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr','result']]
final_df
# Out:
#                        batting_team           bowling_team       city  \
# 124     Royal Challengers Bengaluru  Kolkata Knight Riders  Bangalore
# 125     Royal Challengers Bengaluru  Kolkata Knight Riders  Bangalore
# 126     Royal Challengers Bengaluru  Kolkata Knight Riders  Bangalore
# 127     Royal Challengers Bengaluru  Kolkata Knight Riders  Bangalore
# 128     Royal Challengers Bengaluru  Kolkata Knight Riders  Bangalore
# ...                             ...                    ...        ...
# 213874               Mumbai Indians         Gujarat Titans  Ahmedabad
# 213875               Mumbai Indians         Gujarat Titans  Ahmedabad
# 213876               Mumbai Indians         Gujarat Titans  Ahmedabad
# 213877               Mumbai Indians         Gujarat Titans  Ahmedabad
# 213878               Mumbai Indians         Gujarat Titans  Ahmedabad
#
#         runs_left  balls_left  wickets  total_runs_x       crr        rrr  \
# ...

# %%
# Some bias might be developed as the balls are in continuation of the same match
# Therefore we need to shuffle the rows

final_df = final_df.sample(final_df.shape[0])
final_df
# Out:
#                        batting_team           bowling_team            city  \
# 34686   Royal Challengers Bengaluru         Delhi Capitals           Delhi
# 93087           Chennai Super Kings         Mumbai Indians          Mumbai
# 161968               Mumbai Indians    Sunrisers Hyderabad             NaN
# 75001         Kolkata Knight Riders         Mumbai Indians          Mumbai
# 125012          Sunrisers Hyderabad           Punjab Kings      Chandigarh
# ...                             ...                    ...             ...
# 90580         Kolkata Knight Riders    Chennai Super Kings         Kolkata
# 191321        Kolkata Knight Riders   Lucknow Super Giants            Pune
# 18666                  Punjab Kings  Kolkata Knight Riders  Port Elizabeth
# 43535         Kolkata Knight Riders       Rajasthan Royals         Kolkata
# 177464  Royal Challengers Bengaluru    Sunrisers Hyderabad           Dubai
#
# ...

# %%
# We are dropping the rows which contains any NULL values

final_df.dropna(inplace=True)
final_df.shape
# Out:
# (97485, 10)

# %%
final_df.sample()
# Out:
#           batting_team      bowling_team    city  runs_left  balls_left  \
# 144881  Delhi Capitals  Rajasthan Royals  Jaipur         99          55
#
#         wickets  total_runs_x       crr   rrr  result
# 144881        8           191  8.584615  10.8       1

# %%
# For the final time we are checking if there are any NULL Values.

final_df.isnull().sum()
# Out:
# batting_team    0
# bowling_team    0
# city            0
# runs_left       0
# balls_left      0
# wickets         0
# total_runs_x    0
# crr             0
# rrr             0
# result          0
# dtype: int64

# %%
# An error was encountered in 'required run rate' and it was showing infinite values for some rows.
# Therefore, in order to resolve this, we are selecting only those rows with non-zero 'balls_left' data

final_df = final_df[final_df['balls_left'] != 0]
final_df.shape
# Out:
# (97160, 10)

# %%
# Now we are starting to build the model
# Train test split

X = final_df.iloc[:,:-1] # All the rows except last column
y = final_df.iloc[:,-1] # All the rows with the last column
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#                        batting_team                 bowling_team        city  \
# 190386          Chennai Super Kings  Royal Challengers Bengaluru        Pune
# 130182  Royal Challengers Bengaluru          Sunrisers Hyderabad   Hyderabad
# 116787        Kolkata Knight Riders               Delhi Capitals       Delhi
# 11014                Delhi Capitals               Mumbai Indians       Delhi
# 129182          Chennai Super Kings  Royal Challengers Bengaluru        Pune
# ...                             ...                          ...         ...
# 170163               Delhi Capitals        Kolkata Knight Riders   Ahmedabad
# 5187          Kolkata Knight Riders                 Punjab Kings  Chandigarh
# 68793         Kolkata Knight Riders                 Punjab Kings  Chandigarh
# 106232          Chennai Super Kings               Mumbai Indians      Mumbai
# 176334               Mumbai Indians             Rajasthan Royals     Sharjah
#
# ...

# %%
X_train.describe()
# Out:
#           runs_left    balls_left       wickets  total_runs_x           crr  \
# count  77728.000000  77728.000000  77728.000000  77728.000000  77728.000000
# mean      93.670775     62.529642      7.525152    166.656083      7.482409
# std       50.248061     33.313077      2.147694     29.387098      2.272190
# min       -5.000000     -2.000000      0.000000     62.000000      0.000000
# 25%       54.000000     34.000000      6.000000    148.000000      6.320000
# 50%       93.000000     63.000000      8.000000    166.000000      7.538462
# 75%      131.000000     91.000000      9.000000    187.000000      8.727273
# max      258.000000    119.000000     10.000000    257.000000     36.000000
#
#                 rrr
# count  77728.000000
# mean      10.707554
# std       14.508060
# min     -516.000000
# 25%        7.304348
# 50%        9.000000
# 75%       11.142857
# max      588.000000

# %%
# Our first 3 columns in above dataframe are string and that would create problem
# Therefore we are applying One Hot encoding over it

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse_output=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
# This is the code to train the model with Logistic Regression

pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# This is the code to train the model with Random Forest Classifier 

# pipe = Pipeline(steps=[
#     ('step1',trf),
#     ('step2', RandomForestClassifier())
# ])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred = pipe.predict(X_test)

# %%
# Our model is giving an accuracy of 80.38% with Logistic Regression
# Logistic Regression internally uses sigmoid function and that would tell the probability of win for both team

from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8048065047344586

# %%
# Predicting the probability of both teams

pipe.predict_proba(X_test)[10]
# Out:
# array([0.98894755, 0.01105245])

# %%
# This function will help you to create a dataframe for the 2nd innings of a particular team 

def match_progression(x_df,match_id,pipe):
    match = x_df[x_df['match_id'] == match_id]
    match = match[(match['ball'] == 6)]
    temp_df = match[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr']].dropna()
    temp_df = temp_df[temp_df['balls_left'] != 0]
    result = pipe.predict_proba(temp_df)
    temp_df['lose'] = np.round(result.T[0]*100,1)
    temp_df['win'] = np.round(result.T[1]*100,1)
    temp_df['end_of_over'] = range(1,temp_df.shape[0]+1)
    
    target = temp_df['total_runs_x'].values[0]
    runs = list(temp_df['runs_left'].values)
    new_runs = runs[:]
    runs.insert(0,target)
    temp_df['runs_after_over'] = np.array(runs)[:-1] - np.array(new_runs)
    wickets = list(temp_df['wickets'].values)
    new_wickets = wickets[:]
    new_wickets.insert(0,10)
    wickets.append(0)
    w = np.array(wickets)
    nw = np.array(new_wickets)
    temp_df['wickets_in_over'] = (nw - w)[0:temp_df.shape[0]]
    
    print("Target-",target)
    temp_df = temp_df[['end_of_over','runs_after_over','wickets_in_over','lose','win']]
    return temp_df,target

# %%
# Over by over probability percentage of win and lose of Match ID: 335990

temp_df,target = match_progression(delivery_df,335990,pipe)
temp_df
# Out:
# Target- 214
#       end_of_over  runs_after_over  wickets_in_over  lose   win
# 2010            1                4                0  87.9  12.1
# 2016            2                9                0  84.7  15.3
# 2022            3                5                1  91.2   8.8
# 2028            4               12                0  87.1  12.9
# 2035            5               26                0  64.3  35.7
# 2041            6               16                0  48.3  51.7
# 2047            7                9                0  43.2  56.8
# 2053            8               16                0  28.3  71.7
# 2059            9               12                0  21.0  79.0
# 2065           10                4                1  34.8  65.2
# 2071           11                7                0  32.8  67.2
# 2077           12                5                1  48.1  51.9
# 2083           13                8                0  44.4  55.6
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,8))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=3)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='#00a65a',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.legend(['Wickets in the over', 'Win Probability', 'Losing Probability', 'Runs scored in the Over'])
# plt.legend('Runs scored in the Over')
plt.title('Target-' + str(target))
# Out:
# Text(0.5, 1.0, 'Target-214')

# %%
teams
# Out:
# ['Sunrisers Hyderabad',
#  'Mumbai Indians',
#  'Royal Challengers Bengaluru',
#  'Kolkata Knight Riders',
#  'Punjab Kings',
#  'Chennai Super Kings',
#  'Rajasthan Royals',
#  'Delhi Capitals',
#  'Lucknow Super Giants',
#  'Gujarat Titans']

# %%
delivery_df['city'].unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Kolkata', 'Mumbai', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi', 'Abu Dhabi', nan,
#        'Bengaluru', 'Indore', 'Dubai', 'Sharjah', 'Navi Mumbai',
#        'Lucknow', 'Guwahati'], dtype=object)

# %%
# Pipe object

import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))
